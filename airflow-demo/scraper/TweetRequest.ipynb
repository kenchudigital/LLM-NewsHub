# %% [markdown]
# ## Twitter API v2
#
# sample code: https://github.com/xdevplatform/Twitter-API-v2-sample-code
#
# only retrieve 100 post per month.
#
# Pricing Table:  https://developer.x.com/en/portal/products/pro

# %%
bearer_token = TWITTER_BEARER_TOKEN  # Ensure it's valid

def create_url():
    
    # IF just search targeting to id, it will be success:  
    # tweet_fields = "tweet.fields=lang,author_id"
    # ids = "ids=1278747501642657792,1255542774432063488"
    # url = "https://api.twitter.com/2/tweets?{}&{}".format(ids, tweet_fields)
    
    url = "https://api.twitter.com/2/tweets/search/recent" # [ids,expansions,tweet.fields,media.fields,poll.fields,place.fields,user.fields]"}]
    return url

def connect_to_endpoint(url):
    headers = {
        "Authorization": f"Bearer {bearer_token}",
        "User-Agent": "v2TweetLookupPython",
    }
    MAX_RESULTS = 10 # between 10 and 100
    query = "#AI"
    tweet_fields = "author_id,created_at,text,preview_image_url",
    
    query_params = {
        "query": query,
        "tweet.fields": tweet_fields,
        "max_results": MAX_RESULTS  # Limit to 10 tweets
    }

    response = requests.get(url, headers=headers, params=query_params)
    print(response.status_code)
    if response.status_code == 200:
        return response.json()  # Successfully fetched data
    else:
        raise Exception(
            f"Request returned an error: {response.status_code} {response.text}"
        )

def main():
    url = create_url()
    print('url: ', url)
    try:
        json_response = connect_to_endpoint(url)
        print(json.dumps(json_response, indent=4, sort_keys=True))
    except Exception as e:
        print(e)

if __name__ == "__main__":
    main()

# %%
bearer_token = TWITTER_BEARER_TOKEN  # Ensure it's valid

def create_url():
    
    # IF just search targeting to id, it will be success:  
    # tweet_fields = "tweet.fields=lang,author_id"
    # ids = "ids=1278747501642657792,1255542774432063488"
    # url = "https://api.twitter.com/2/tweets?{}&{}".format(ids, tweet_fields)
    
    url = "https://api.twitter.com/2/tweets/search/recent" # [ids,expansions,tweet.fields,media.fields,poll.fields,place.fields,user.fields]"}]
    return url

def connect_to_endpoint(url):
    headers = {
        "Authorization": f"Bearer {bearer_token}",
        "User-Agent": "v2TweetLookupPython",
    }
    MAX_RESULTS = 10 # between 10 and 100
    query = "#AI"
    tweet_fields = "author_id,created_at,text,preview_image_url",
    
    query_params = {
        "query": query,
        "tweet.fields": tweet_fields,
        "max_results": MAX_RESULTS  # Limit to 10 tweets
    }

    response = requests.get(url, headers=headers, params=query_params)
    print(response.status_code)
    if response.status_code == 200:
        return response.json()  # Successfully fetched data
    else:
        raise Exception(
            f"Request returned an error: {response.status_code} {response.text}"
        )

def main():
    url = create_url()
    print('url: ', url)
    try:
        json_response = connect_to_endpoint(url)
        print(json.dumps(json_response, indent=4, sort_keys=True))
    except Exception as e:
        print(e)

if __name__ == "__main__":
    main()
